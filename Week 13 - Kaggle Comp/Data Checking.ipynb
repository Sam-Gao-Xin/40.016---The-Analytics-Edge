# %%
import pandas as pd

# %%
df = pd.read_csv("cleaned_train_df.csv")

# %%
pd.set_option('display.max_rows', 240)
df.dtypes
# Out:
# Unnamed: 0      int64
# enjoy           int64
# rainy           int64
# cloudy          int64
# link            int64
# mostly          int64
# weather         int64
# can             int64
# day             int64
# good            int64
# issue           int64
# new             int64
# news            int64
# open            int64
# hail            int64
# move            int64
# north           int64
# possible        int64
# thunderstorm    int64
# will            int64
# expect          int64
# high            int64
# isolate         int64
# low             int64
# rain            int64
# shower          int64
# snow            int64
# south           int64
# today           int64
# ass             int64
# make            int64
# sleep           int64
# wanna           int64
# keep            int64
# mention         int64
# now             int64
# please          int64
# storm           int64
# tomorrow        int64
# degree          int64
# humidity        int64
# ...
